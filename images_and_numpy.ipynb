# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('image1.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr= np.asarray(pic) #array'e çevirdik.

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (664, 750, 3)

# %%
plt.imshow(pic_arr) #array dağılımı böyle görebiliyoruz.

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (664, 750, 3)

# %%
plt.imshow(pic_red[:,:,0]) #red,green,blue
pic_red[:,:,0] #viridis renk koduna göre ayarlıyor. mordan sarıya kadar
# Out:
# array([[249, 249, 249, ..., 252, 252, 252],
#        [250, 249, 249, ..., 252, 252, 252],
#        [249, 249, 249, ..., 252, 252, 252],
#        ...,
#        [195, 195, 195, ...,  73,  76,  77],
#        [195, 195, 195, ...,  73,  75,  77],
#        [195, 195, 195, ...,  73,  75,  77]], dtype=uint8)

# %%
#red channel values 0-255 (0=hiç kırmızı yok, tamamen siyah , 255= pürüzsüz kırmızı)
plt.imshow(pic_red[:,:,0],cmap='gray') #bu resim özelinde beyaza yakınsa daha kırmızı demektir.

# %%
plt.imshow(pic_red[:,:,1],cmap='gray') #green

# %%
plt.imshow(pic_red[:,:,2],cmap='gray') #blue

# %%
#Yeşil kanaldaki her şeyi 0 ladık.
pic_red[:,:,1] = 0

# %%
plt.imshow(pic_red)

# %%
#mavi kanaldaki her şeyi 0 ladık.
pic_red[:,:,2] = 0
plt.imshow(pic_red) #sadece kırmızı gösteriyor.
