# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('image1.jpg') #file path önemli.

# %%
type(img) #direkt numpy array oluyor.
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[234, 238, 249],
#         [234, 238, 249],
#         [234, 238, 249],
#         ...,
#         [218, 233, 252],
#         [218, 233, 252],
#         [218, 233, 252]],
#
#        [[235, 239, 250],
#         [234, 238, 249],
#         [234, 238, 249],
#         ...,
#         [218, 233, 252],
#         [218, 233, 252],
#         [218, 233, 252]],
#
#        [[234, 238, 249],
#         [234, 238, 249],
#         [234, 238, 249],
#         ...,
#         [218, 233, 252],
#         [218, 233, 252],
#         [218, 233, 252]],
#
#        ...,
#
#        [[101, 144, 195],
#         [101, 144, 195],
#         [101, 144, 195],
#         ...,
#         [ 21,  37,  73],
#         [ 24,  40,  76],
#         [ 25,  41,  77]],
#
#        [[101, 144, 195],
#         [101, 144, 195],
#         [101, 144, 195],
#         ...,
#         [ 21,  37,  73],
#         [ 23,  39,  75],
#         [ 25,  41,  77]],
#
#        [[101, 144, 195],
#         [101, 144, 195],
#         [101, 144, 195],
# ...

# %%
img.shape
# Out:
# (664, 750, 3)

# %%
plt.imshow(img)

# %% [markdown]
# matplotlib --> RGB OKUR RED GREEN BLUE.
# OPENCV -->BGR BLUE GREEN RED OKUYOR.

# %%
fixedimg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #rgb'ye dönüştürmek için.

# %%
plt.imshow(fixedimg)

# %%
img_gray = cv2.imread('image1.jpg',cv2.IMREAD_GRAYSCALE) #Direkt grayscale okumak için.

# %%
img_gray.shape #3. kanalı yok renk için olan
# Out:
# (664, 750)

# %%
plt.imshow(img_gray,cmap='gray') #Yine cmap olarak gray yapman lazım ki farklı okumasın.

# %%
plt.imshow(img_gray,cmap='magma')

# %%
plt.imshow(fixedimg)

# %%
fixedimg.shape
# Out:
# (664, 750, 3)

# %%
newimage =cv2.resize(fixedimg,(400,300)) #400 x , 300 y oluyor

# %%
plt.imshow(newimage)

# %%
width_ratio = 0.8
height_ratio = 0.2 # oran gibi yapmak için

# %%
newimage=cv2.resize(fixedimg,(0,0),fixedimg,width_ratio,height_ratio)

# %%
plt.imshow(newimage)

# %%
flippedimg= cv2.flip(fixedimg,1) #0 baş aşağı, 1 y eksenine göre, -1 ikisi birden
plt.imshow(flippedimg)

# %%
type(flippedimg)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('aykut_ama_ters.jpg',flippedimg) #farklı kaydetmek için
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(fixedimg) # bu kod ile canvası ayarlayıp şekli orijinal boyutuna yaklaştırıyoruz ama ileride fonksiyon olacak.
