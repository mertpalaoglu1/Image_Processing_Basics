# %%
import numpy as np

# %%
myArray=np.ones((5,5))
myArray*10 #her elemanı 10'la çarptık.
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
np.random.seed(31)
arr=np.random.randint(low=0,high=101,size=(3,3))
arr
# Out:
# array([[82, 87, 16],
#        [98, 23, 58],
#        [28, 93, 92]])

# %%
arr.max()
# Out:
# 98

# %%
arr.min()
# Out:
# 16

# %%
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mypicture = Image.open('image1.jpg')

# %%
mypicture
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x664>

# %%
picArray=np.asarray(mypicture)

# %%
picArray.shape
# Out:
# (664, 750, 3)

# %%
plt.imshow(picArray) #kopyalamak lazım yoksa ilk picture readonly oluyor.
copiedPicArray=np.copy(picArray)
#r g b
copiedPicArray[:,:,1]=0 #green kısmını 0 ladım
copiedPicArray[:,:,0]=0 #red kısmını 0 ladım
plt.imshow(copiedPicArray)
